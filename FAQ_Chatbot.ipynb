# %%
# !pip install nltk scikit-learn

# %%
import nltk
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Upgrade NLTK to ensure it's the latest version and resolve potential internal issues
# !pip install --upgrade nltk

nltk.download('punkt')

# FAQs data
faqs = {
    "What is Artificial Intelligence?":
        "Artificial Intelligence is the simulation of human intelligence in machines.",
    "What is Machine Learning?":
        "Machine Learning is a subset of AI that allows systems to learn from data.",
    "What is Deep Learning?":
        "Deep Learning uses neural networks with many layers to analyze data.",
    "What is Python used for?":
        "Python is used for AI, machine learning, web development, and data analysis.",
    "What is CodeAlpha?":
        "CodeAlpha is a platform that provides internships and training programs."
}

questions = list(faqs.keys())
answers = list(faqs.values())

def chatbot_response(user_input):
    corpus = questions + [user_input]

    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(corpus)

    similarity = cosine_similarity(tfidf_matrix[-1], tfidf_matrix[:-1])
    index = similarity.argmax()

    return answers[index]

# Chat loop
print("🤖 FAQ Chatbot (type 'exit' to stop)\n")

while True:
    user_question = input("You: ")

    if user_question.lower() == "exit":
        print("Chatbot: Goodbye 👋")
        break

    response = chatbot_response(user_question)
    print("Chatbot:", response)
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 🤖 FAQ Chatbot (type 'exit' to stop)
#
# You: What is Artificial Intelligence?
# Chatbot: Artificial Intelligence is the simulation of human intelligence in machines.
# You: What is CodeAlpha?
# Chatbot: CodeAlpha is a platform that provides internships and training programs.
# You: exit
# Chatbot: Goodbye 👋
